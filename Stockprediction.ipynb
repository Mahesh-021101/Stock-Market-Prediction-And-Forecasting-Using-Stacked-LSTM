# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import io
import requests 
import datetime

# %%
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
df = pd.read_csv(url)
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df.shape
# Out:
# (2035, 8)

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
df.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
sns.set(rc = {'figure.figsize': (20, 8)})
df['Open'].plot(linewidth = 1,color='red')
# Out:
# <AxesSubplot:>

# %%
cols_plot = ['Open','High','Low','Last','Close']
axes = df[cols_plot].plot(alpha = 1, figsize=(20, 20), subplots = True)

for ax in axes:
    ax.set_ylabel('Variation')

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']
df
# Out:
#                  Date    Open    High     Low    Last   Close  \
# Date
# 2018-09-28 2018-09-28  234.05  235.95  230.20  233.50  233.75
# 2018-09-27 2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2018-09-26 2018-09-26  240.00  240.00  232.50  235.00  234.25
# 2018-09-25 2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2018-09-24 2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...               ...     ...     ...     ...     ...     ...
# 2010-07-27 2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2010-07-26 2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2010-07-23 2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2010-07-22 2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2010-07-21 2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-09-28               3069914          7162.35
# 2018-09-27               5082859         11859.95
# 2018-09-26               2240909          5248.60
# 2018-09-25               2349368          5503.90
# 2018-09-24               3423509          7999.55
# ...                          ...              ...
# 2010-07-27                586100           694.98
# 2010-07-26                658440           780.01
# 2010-07-23                281312           340.31
# 2010-07-22                293312           355.17
# 2010-07-21                658666           803.56
#
# [2035 rows x 8 columns]

# %%
del df["Date"]
df.dtypes
# Out:
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %%
df2=df.reset_index()['Open']
df2
# Out:
# 0       234.05
# 1       234.55
# 2       240.00
# 3       233.30
# 4       233.55
#          ...
# 2030    117.60
# 2031    120.10
# 2032    121.80
# 2033    120.30
# 2034    122.10
# Name: Open, Length: 2035, dtype: float64

# %%
plt.plot(df2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df2=scaler.fit_transform(np.array(df2).reshape(-1,1))
print(df2)
# Out:
# [[0.6202352 ]
#  [0.62226277]
#  [0.64436334]
#  ...
#  [0.16504461]
#  [0.15896188]
#  [0.16626115]]

# %%
train_size=int(len(df2)*0.75)
test_size=len(df2)-train_size
train_data,test_data=df2[0:train_size,:],df2[train_size:len(df2),:1]
train_size,test_size
# Out:
# (1526, 509)

# %%
def create_dataset(dataset, time_step=1):
    train_X, train_Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        train_X.append(a)
        train_Y.append(dataset[i + time_step, 0])
    return numpy.array(train_X), numpy.array(train_Y)

# %%
import numpy
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

print(X_train.shape), print(y_train.shape)
# Out:
# (1425, 100)
# (1425,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=50,batch_size=64,verbose=1)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 23s 345ms/step - loss: 0.0195 - val_loss: 0.0097
# Epoch 2/50
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0029 - val_loss: 7.4872e-04
# Epoch 3/50
# 23/23 [==============================] - 5s 228ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 4/50
# 23/23 [==============================] - 5s 217ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 5/50
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0018 - val_loss: 9.5055e-04
# Epoch 6/50
# 23/23 [==============================] - 6s 256ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 7/50
# 23/23 [==============================] - 5s 201ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch
# 23/23 [==============================] - 5s 209ms/step - loss: 5.5277e-04 - val_loss: 5.4194e-04
# Epoch 33/50
# 23/23 [==============================] - 7s 325ms/step - loss: 5.6068e-04 - val_loss: 5.4263e-04
# Epoch 34/50
# 23/23 [==============================] - 5s 216ms/step - loss: 5.5018e-04 - val_loss: 5.3918e-04
# Epoch 35/50
# 23/23 [==============================] - 6s 264ms/step - loss: 5.5657e-04 - val_loss: 5.2216e-04
# Epoch 36/50
# 23/23 [==============================] - 5s 214ms/step - loss: 5.4727e-04 - val_loss: 4.4340e-04
# Epoch 37/50
# 23/23 [==============================] - 5s 214ms/step - loss: 4.7790e-04 - val_loss: 3.9239e-04
# Epoch 38/50
# 23/23 [==============================] - 6s 258ms/step - loss: 5.1239e-04 - val_loss: 3.6049e-04
# Epoch 39/50
# 23/23 [==============================] - 5s 208ms/step - loss: 4.4771e-04 - val_loss: 3.3500e-04
# Epoch 40/50
# 23/23 [==============================] - 6s 262ms/step - loss: 5.4630e-04 - val_loss: 4.4527e-04
# Epoch 41/50
# 23/23 [==============================] - 5s 212ms/step - loss: 4.3293e-04 - val_loss: 4.8543e-04
# Epoch 42/50
# 23/23 [==============================] - 5s 223ms/step - loss: 4.1382e-04 - val_loss: 5.0474e-04
# Epoch 43/50
# 23/23 [==============================] - 6s 245ms/step - loss: 4.3646e-04 - val_loss: 3.8985e-04
# Epoch 44/50
# 23/23 [==============================] - 5s 214ms/step - loss: 4.0279e-04 - val_loss: 3.4706e-04
# Epoch 45/50
# 23/23 [==============================] - 6s 269ms/step - loss: 3.9399e-04 - val_loss: 3.3251e-04
# Epoch 46/50
# 23/23 [==============================] - 5s 214ms/step - loss: 3.7913e-04 - val_loss: 3.8867e-04
# Epoch 47/50
# 23/23 [==============================] - 6s 258ms/step - loss: 3.4421e-04 - val_loss: 4.1357e-04
# Epoch 48/50
# 23/23 [==============================] - 5s 212ms/step - loss: 3.4561e-04 - val_loss: 2.9146e-04
# Epoch 49/50
# 23/23 [==============================] - 5s 211ms/step - loss: 3.2641e-04 - val_loss: 3.1087e-04
# Epoch 50/50
# 23/23 [==============================] - 6s 269ms/step - loss: 3.4596e-04 - val_loss: 3.6213e-04

# %%
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
# Out:
# 45/45 [==============================] - 4s 62ms/step
# 13/13 [==============================] - 1s 45ms/step

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 163.24271180472797

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 107.3771338565574

# %%
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict

# %%
pred  = scaler.inverse_transform(df2)
plt.plot(pred,color='blue')
plt.show()

# %%
plt.plot(trainPredictPlot,color='red')
plt.show()
plt.plot(testPredictPlot,color='green')
plt.show()

# %%
plt.plot(pred,color='blue')
plt.plot(trainPredictPlot,color='red')
plt.plot(testPredictPlot,color='green')
plt.show()
